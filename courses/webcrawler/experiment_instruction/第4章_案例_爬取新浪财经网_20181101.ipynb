# %% [markdown]
# # “网络数据采集” 课程
#
# # 第4章 Web内容解析

# %% [markdown]
# ## 案例名称
#
# 爬取新浪财经网http://finance.sina.com.cn/stock/，各股票公司每日公告（爬取股票分析所需语料）
#
# ## 案例内容
#
# 本案例用于爬取新浪财经股票公司公告。
#
# 基本流程如下：
#
# 1. 输入开始日期、结束日期，作为查询条件，之后程序后计算之间有多少天，之后生成每一天的日期，以每天的日期作为查询条件提交到 http://vip.stock.finance.sina.com.cn/corp/view/vCB_BulletinGather.php?gg_date=&ftype=0 进行查询。
#
# 2. 程序采用了多线程技术加速爬取过程。每个线程都将首先执行spiderOneGroupDays；
#
# 3. 调用 spiderOneDay
#
# 4. 调用 spiderOnePage
#
# 5. 调用 spiderOnePiece

# %%
## coding:utf-8
# 爬取新浪财经网股票公司每日公告
# 提供日期即可  eg: 2017-02-21
import os
import math
import time
import datetime
import requests
import threading
from lxml import etree


# 爬取一条公告并保存
def spiderOnePiece(iurl,headers,datetime,base_dir,filename):
    # 去除文件名中的非法字符
    invaild=['*','\\','/',':','\"','<','>','|','?']
    for c in invaild:
        if c in filename:
            filename=filename.replace(c,'')
    print("    公告链接为：",iurl)
    try:
        response=requests.get(iurl,headers=headers)
        response.raise_for_status()
        response.encoding = response.apparent_encoding
        
        page=etree.HTML(response.text)
        content=page.xpath('//*[@id="content"]/pre')
        if len(content)==0:
            return
        content=content[0].text
        print(content[:20])
        filename = os.path.join(base_dir,datetime,filename)
        with open(filename,'w+') as f:
            f.write(content)
    except Exception as e:
        print("spiderOnePiece error:",e)

# 爬取一页
def spiderOnePage(url,headers,datetime,base_dir):
    website='http://vip.stock.finance.sina.com.cn'
    try:
        response=requests.get(url,headers=headers)
        response.encoding = response.apparent_encoding
        response.raise_for_status()
    
        page=etree.HTML(response.text)
        trList=page.xpath(r'//*[@id="wrap"]/div[@class="Container"]/table/tbody/tr')

        print("当前页面共有公告{}条".format(len(trList) ))
        if len(trList)==1:  # 爬取结束  该行（对不起没有相关记录）
            return 0

        #按日期建立文件目录
        a_dirByDate = os.path.join(base_dir,datetime)
        if not os.path.exists(a_dirByDate):  # 创建日期文件夹
            os.mkdir(a_dirByDate)

        for item in trList:
            aUrl=item.xpath('th/a[1]')
            title=aUrl[0].text    # 公告标题
            href=aUrl[0].attrib['href']   # 公告uri
            href=website+href    # 公告url

            atype=item.xpath('td[1]')[0].text # 公告类型
            print("准备爬取公告{}".format(title))
            a_filename = title+atype+'.txt'
            print("    存储位置：",a_filename)
            spiderOnePiece(href,headers,datetime,base_dir,a_filename)
        return 1
    except Exception as e:
        print(e)

# 爬取一天
def spiderOneDay(url,headers,datetime,base_dir='company_annoucement'):
    url=url.replace('#datetime#',datetime)  # 填充日期
    flag=1   # 爬取成功标志
    index=1  # 起始页
    
    log_dir = os.path.join(base_dir,'log')
    print(log_dir)
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    log_file = os.path.join(log_dir,datetime+'.log')    
    
    with open(log_file,'w') as f:
        while flag:
            t_url=url+str(index)
            try:
                flag=spiderOnePage(t_url,headers,datetime,base_dir)
            except Exception as e:
                print('spiderOneDay err:',e)
                flag=0
            finally:
                if flag:
                    print('%s page_%d load success,continue.' %(datetime,index))
                    f.write('%s_page_%d load success.\n' %(datetime,index))
                    f.flush()
                else:
                    print('%s page_%d load fail,end.' %(datetime,index))
                    f.write('%s_page_%d load failed.\n' %(datetime,index))
                    f.flush()
                index+=1
    

# 爬取一组天股票公司的数据
def spiderOneGroupDays(url,headers,date_group,base_dir):
    for idate in date_group:
        try:

            spiderOneDay(url,headers,idate,base_dir)
            print('%s has load success.over.' %idate)
        except Exception as e:
            print('spiderOneGroupDays err:',e)
            continue


# 获取指定起始日期[包含]--结束日期[包含]之间的日期  
def getBetweenDay(begin_date,end_date):
    date_list=[]
    begin_date=datetime.datetime.strptime(begin_date,'%Y-%m-%d')
    # 现在的日期
    now_date=datetime.datetime.strptime(time.strftime('%Y-%m-%d',time.localtime(time.time())),'%Y-%m-%d')
    end_date=datetime.datetime.strptime(end_date,'%Y-%m-%d')
    # 如果给出的结束日期大于现在的日期  则将今天的日期作为结束日期
    if end_date > now_date:
        end_date = now_date
    while begin_date <= end_date:
        date_str=begin_date.strftime('%Y-%m-%d')
        date_list.append(date_str)
        begin_date+=datetime.timedelta(days=1)
    return date_list

# 将date_list 平均分成threadNum组  最后一组可能较少
def split_date_list(date_list,threadNum):
    # length=(len(date_list)/threadNum if len(date_list)%threadNum==0 else len(date_list)/threadNum+1)
    length=int(math.ceil(len(date_list)*1.0/threadNum))
    return [date_list[m:m+length] for m in range(0,len(date_list),length)]

def main():
    headers = {
        "Accept-Language": "zh-CN,zh;q=0.8", 
        "Accept-Encoding": "gzip, deflate, sdch", 
        "Host": "vip.stock.finance.sina.com.cn", 
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8", 
        "Upgrade-Insecure-Requests": "1", 
        "Connection": "keep-alive", 
        "User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36"
    }
    
    url='http://vip.stock.finance.sina.com.cn/corp/view/vCB_BulletinGather.php?gg_date=#datetime#&page='
    
    # 创建数据与日志的保存文件夹
    base_dir = "company_announcements"
    if not os.path.exists(base_dir):
        os.mkdir(base_dir)
    
    # datetime='2017-02-19'
    # spiderOneDay(url,headers,datetime,log_path)
    #symbol = input("请输入A股股票的代码/名称/拼音")
    begin_date = input("请输入需查询的开始日期（例如：2017-01-01）：")
    end_date = input("请输入需查询的结束日期（例如：2017-01-31）：")
    # begin_date[包含]-->end_date[包含] 之间的所有date
    date_list = getBetweenDay(begin_date,end_date)
    print('%s 到 %s，共 %d 天。' % (begin_date,end_date,len(date_list)))
    
    # begin_date[包含]-->end_date[包含] 之间的所有date
    date_list=getBetweenDay(begin_date,end_date)
    print('%s-%s:%d days.' %(begin_date,end_date,len(date_list)))

    cut_date_list=split_date_list(date_list,4)
    print(cut_date_list)

    threads=[]
    for dgroup in cut_date_list:
        t=threading.Thread(target=spiderOneGroupDays,args=(url,headers,dgroup,base_dir))
        threads.append(t)

    # 开始线程
    for t in threads:
        t.start()

    # 等待所有线程结束  阻塞主线程
    for t in threads:
        t.join()
    print('all load success...')
    
if __name__ == '__main__':
    main()
# Out:
# 请输入需查询的开始日期（例如：2017-01-01）：2017-01-01
# 请输入需查询的结束日期（例如：2017-01-31）：2017-01-04
# 2017-01-01 到 2017-01-04，共 4 天。
# 2017-01-01-2017-01-04:4 days.
临时股东大会决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80036750&gather=1&id=2982813
# 深圳市联建光电股份有限公司
#
# 准备爬取公告创智5：关于子公司签订《深圳市财政专项基金股权投资项目合同书》的公告　　安信证券关于和谐光灿向华灿光电及其控
#
#     存储位置： 创智5：关于子公司签订《深圳市财政专项基金股权投资项目合同书》的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=10001084&gather=1&id=2982642
# 准备爬取公告科融环境：第三届监事会第十七次会议（临时）决议公告
#     存储位置： 科融环境：第三届监事会第十七次会议（临时）决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980420
# 公告内容详见附件
# 准备爬取公告数码3：兴业证券股份有限公司关于陕西煤航数码测绘(集团)股份有限公司重大事项风险提示公告徐州科融环境资源股份有限公司
#
#     存储位置： 数码3：兴业证券股份有限公司关于陕西煤航数码测绘(集团)股份有限公司重大事项风险提示公告券商报告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=10000507&gather=1&id=2982641
#
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 2273: illegal multibyte sequence
# 准备爬取公告华灿光电：独立董事关于拟接受关联公司财务资助的独立意见
#     存储位置： 华灿光电：独立董事关于拟接受关联公司财务资助的独立意见临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80198532&gather=1&id=2980419
# 华灿光电股份有限公司独立董事
#
# 公告内容详见附件
# 准备爬取公告科融环境：独立董事公开征集委托投票权报告书
#     存储位置： 科融环境：独立董事公开征集委托投票权报告书临时公告.txt
#     公告链接为： 准备爬取公告数码3：陕西煤航数码测绘(集团)股份有限公司重大事项进展情况的公告http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980418
#
#     存储位置： 数码3：陕西煤航数码测绘(集团)股份有限公司重大事项进展情况的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=10000507&gather=1&id=2982639
# 公告内容详见附件
# 准备爬取公告和晶科技：关于全资子公司与陕西广电网络传媒（集团）股份有限公司签署合作框架协议书的公告
# 徐州科融环境资源股份有限公司
#         存储位置： 和晶科技：关于全资子公司与陕西广电网络传媒（集团）股份有限公司签署合作框架协议书的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80187840&gather=1&id=2982605
#
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 4028: illegal multibyte sequence
# 准备爬取公告科融环境：北京谦��律师事务所关于公司股票期权激励计划的法律意见书
#     存储位置： 科融环境：北京谦��律师事务所关于公司股票期权激励计划的法律意见书法律意见书.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980417
# 无锡和晶科技股份有限公司公告文件
#
# 准备爬取公告奥克股份：关于股东减持计划的提示性公告
#     存储位置： 奥克股份：关于股东减持计划的提示性公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80082008&gather=1&id=2982604
# 北京谦��律师事务所
# 关于徐州科融环境
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 3: illegal multibyte sequence
# 准备爬取公告科融环境：监事会关于第一期股票期权激励计划激励对象名单的核查意见
#     存储位置： 科融环境：监事会关于第一期股票期权激励计划激励对象名单的核查意见临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980416
# 辽宁奥克化学股份有限公司
# spiderOnePiece error: 徐州科融环境资源股份有限公司监事会
#  'gbk' codec can't encode character '\ufffd' in position 1223: illegal multibyte sequence
#
# 准备爬取公告和佳股份：2017年第一次临时股东大会决议公告
#     存储位置： 和佳股份：2017年第一次临时股东大会决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80180702&gather=1&id=2982603
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 1978: illegal multibyte sequence
# 准备爬取公告科融环境：第三届董事会第二十九次会议（临时）决议公告
#     存储位置： 科融环境：第三届董事会第二十九次会议（临时）决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980415
# 珠海和佳医疗设备股份有限公司
#
# 准备爬取公告和佳股份：2017年第一次临时股东大会的法律意见书徐州科融环境资源股份有限公司
#
#
#     存储位置： 和佳股份：2017年第一次临时股东大会的法律意见书法律意见书.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80180702&gather=1&id=2982602
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 2542: illegal multibyte sequence
# 准备爬取公告科融环境：上市公司股权激励计划自查表
#     存储位置： 科融环境：上市公司股权激励计划自查表临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980414
# 关于
# 珠海和佳医疗设备股份有限公司
#
# 准备爬取公告纳川股份：关于持股5%以上股东部分股权质押的公告上市公司股权激励计划自查表
#
#     存储位置：
#  纳川股份：关于持股5%以上股东部分股权质押的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80167840&gather=1&id=2982568
# 准备爬取公告科融环境：关于召开公司2017年第一次临时股东大会的通知
#     存储位置： 科融环境：关于召开公司2017年第一次临时股东大会的通知临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980411
# 关于持股 5%以上股东部分股权质押的公告
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 1373: illegal multibyte sequence徐州科融环境资源股份有限公司
#
#
# 准备爬取公告东华测试：简式权益变动报告书
#     存储位置： 东华测试：简式权益变动报告书临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80198746&gather=1&id=2982440
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 2328: illegal multibyte sequence
# 准备爬取公告科融环境：第一期股票期权激励计划激励对象名单
#     存储位置： 科融环境：第一期股票期权激励计划激励对象名单临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980410
# 徐州科融环境资源股份有限公司
#
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 2667: illegal multibyte sequence
# 江苏东华测试技术股份有限公司
#     准备爬取公告科融环境：第一期股票期权激励计划实施考核管理办法
#     存储位置： 科融环境：第一期股票期权激励计划实施考核管理办法临时公告.txt
#     公告链接为：
# http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80145033&gather=1&id=2980408
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 467: illegal multibyte sequence
# 准备爬取公告东华测试：关于控股股东减持股份的公告
#     存储位置： 东华测试：关于控股股东减持股份的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80198746&gather=1&id=2982439
# 江苏东华测试技术股份有限公司
#
# spiderOnePiece error:徐州科融环境资源股份有限公司
#      'gbk' codec can't encode character '\ufffd' in position 345: illegal multibyte sequence
#
# 准备爬取公告锦浪科技：主办券商关于股票发行合法合规性意见
#     存储位置： 锦浪科技：主办券商关于股票发行合法合规性意见券商报告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80543678&gather=1&id=2982409
# 准备爬取公告健帆生物：2017年第一次临时股东大会决议公告
#     存储位置： 健帆生物：2017年第一次临时股东大会决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80198447&gather=1&id=2980329
# 珠海健帆生物科技股份有限公司
#
# spiderOnePiece error:公告内容详见附件 'gbk' codec can't encode character '\ufffd' in position 1917: illegal multibyte sequence
#
# 准备爬取公告健帆生物：2017年第一次临时股东大会的法律意见书
#     存储位置： 健帆生物：2017年第一次临时股东大会的法律意见书法律意见书.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80198447&gather=1&id=2980327
# 准备爬取公告药石科技：2017年第一次临时股东大会决议公告
#     存储位置： 药石科技：2017年第一次临时股东大会决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80148386&gather=1&id=2982350
# 深圳北京上海广州杭州天津昆明成都宁波福州
# 准备爬取公告星河生物：关于对外投资在美国设立境外全资子公司的公告公告内容详见附件
#     存储位置： 星河生物：关于对外投资在美国设立境外全资子公司的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80156738&gather=1&id=2980324
#
# 准备爬取公告东软载波：2016年度业绩预告
#     存储位置： 东软载波：2016年度业绩预告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80166377&gather=1&id=2982302
# 青岛东软载波科技股份有限公司
#
# spiderOnePiece error: 广东星河生物科技股份有限公司
#
# 'gbk' codec can't encode character '\ufffd' in position 1092: illegal multibyte sequence
# 准备爬取公告金石东方：海通证券股份有限公司关于公司2016年定期现场检查报告
#     存储位置： 金石东方：海通证券股份有限公司关于公司2016年定期现场检查报告券商报告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80200092&gather=1&id=2982226
# spiderOnePiece error: 'gbk' codec can't encode character '\ufffd' in position 1857: illegal multibyte sequence
# 准备爬取公告爱尔眼科：关于全资子公司爱尔（美国）国际控股有限责任公司拟收购股权资产的公告
#     存储位置： 爱尔眼科：关于全资子公司爱尔（美国）国际控股有限责任公司拟收购股权资产的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80122399&gather=1&id=2980288
# 海通证券股份有限公司关于四川金石东方新材
# 准备爬取公告金石东方：海通证券股份有限公司关于公司2016年度现场培训情况的报告爱尔眼科医院集团股份有限公司
# 关于全资
#
#     存储位置： 金石东方：海通证券股份有限公司关于公司2016年度现场培训情况的报告券商报告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80200092&gather=1&id=2982224
# 2017-01-03 page_1 load success,continue.
# 当前页面共有公告30条
# 准备爬取公告爱尔眼科：独立董事关于相关事项的独立意见
#     存储位置： 爱尔眼科：独立董事关于相关事项的独立意见临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80122399&gather=1&id=2980287
# 海通证券股份有限公司
#       关于
# 准备爬取公告汉鼎宇佑：关于公司项目列入杭州市国家高端软件及应用系统集聚发展试点实施项目及获得财政补助的公告
#     存储位置： 汉鼎宇佑：关于公司项目列入杭州市国家高端软件及应用系统集聚发展试点实施项目及获得财政补助的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80194238&gather=1&id=2982195
# 爱尔眼科医院集团股份有限公司
#
# 准备爬取公告爱尔眼科：第四届董事会第三次会议决议公告汉鼎宇佑互联网股份有限公司
#  关于公司
#
#     存储位置： 爱尔眼科：第四届董事会第三次会议决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80122399&gather=1&id=2980286
# 准备爬取公告奥飞数据：2016年第九次临时股东大会决议公告
#     存储位置： 奥飞数据：2016年第九次临时股东大会决议公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80525543&gather=1&id=2982189
# 爱尔眼科医院集团股份有限公司
#
# 公告内容详见附件
# 准备爬取公告晨曦航空：股票交易异常波动及风险提示公告
#     存储位置： 晨曦航空：股票交易异常波动及风险提示公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80457913&gather=1&id=2980280
# 准备爬取公告濮阳惠成：关于公司持股5%以上股东股份减持计划的提示性公告
#     存储位置： 濮阳惠成：关于公司持股5%以上股东股份减持计划的提示性公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80312050&gather=1&id=2982186
# 濮阳惠成电子材料股份有限公司
#
# 2017-01-04 page_2 load success,continue.
# 西安晨曦航空科技股份有限公司
#
# 准备爬取公告向日葵：浙商证券股份有限公司关于公司发行股份及支付现金购买资产并募集配套资金暨关联交易申请文件反馈意见回复的核查意见
#     存储位置： 向日葵：浙商证券股份有限公司关于公司发行股份及支付现金购买资产并募集配套资金暨关联交易申请文件反馈意见回复的核查意见券商报告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80133641&gather=1&id=2980275
# 当前页面共有公告30条
# 准备爬取公告美尚生态：关于部分董事、高级管理人员减持计划的提示性公告
#     存储位置： 美尚生态：关于部分董事、高级管理人员减持计划的提示性公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80202027&gather=1&id=2982184
# 美尚生态景观股份有限公司
#
# 准备爬取公告长方集团：关于公司参与设立教育产业投资并购基金签订投资协议进展的公告
#     存储位置： 长方集团：关于公司参与设立教育产业投资并购基金签订投资协议进展的公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80193002&gather=1&id=2982138
# 深圳市长方集团股份有限公司
#
# 准备爬取公告南京证券：股票暂停转让进展公告
#     存储位置： 南京证券：股票暂停转让进展公告临时公告.txt
#     公告链接为： http://vip.stock.finance.sina.com.cn/corp/view/vCB_AllBulletinDetail.php?CompanyCode=80000051&gather=1&id=2982124

# %% [markdown]
# ## 案例结论
#
# 这个案例较为综合的演示了：
#
# - 使用requests库爬取sina股票网站的公司公告
#
# - 使用lxml的xpath解析文档内容，提取公告文本
#
# - 使用多线程技术，加速爬取。

# %%
import os

base_dir = "company"
a = os.path.join(base_dir,'log','123','444')
a
